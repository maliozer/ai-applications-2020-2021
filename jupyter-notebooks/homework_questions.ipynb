# %% [markdown]
# #The chess game
#
# The chessboard occurs from 8x8  dark and light squares.
# It is a good example of a multidimensional arrays and matrixes.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Q1 Build a 8x8 empty chessboard in python with using list() object.
# Recall that the list object can be defined as ```mylist = []```
#
# The list object may include any type of data, nested lists also can be defined as a multidimensional structure.
#
# ```python
# mylist = [
#   [],
#   [],
#   ...
#   ...
#   []
# ]
# ```

# %% [markdown]
# ##Answer1

# %%
#hardcoded
board = [
      [None, None, None, None, None, None, None, None],
      [None, None, None, None, None, None, None, None],
      [None, None, None, None, None, None, None, None],
      [None, None, None, None, None, None, None, None],
      [None, None, None, None, None, None, None, None],
      [None, None, None, None, None, None, None, None],
      [None, None, None, None, None, None, None, None],
      [None, None, None, None, None, None, None, None]
]

#or with loops
chessboard = list()
for x in range(8):
  row = list()
  for y in range(8):
    row.append(None)
  chessboard.append(row)

# %%
print(board)
# Out:
# [[None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None]]

# %%
print(chessboard)
# Out:
# [[None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None]]

# %% [markdown]
# #Q2 Try to fill the chessboard's row of 2nd and row of 7th row with WPawn (White Pawn) and BPawn (Black Pawn) respectively.

# %%
board = [
         [None,None,None,None,None,None,None,None],
         ["BPawn","BPawn","BPawn","BPawn","BPawn","BPawn","BPawn","BPawn"],
         [None,None,None,None,None,None,None,None],
         [None,None,None,None,None,None,None,None],
         [None,None,None,None,None,None,None,None],
         [None,None,None,None,None,None,None,None],
         ["WPawn","WPawn","WPawn","WPawn","WPawn","WPawn","WPawn","WPawn"],
         [None,None,None,None,None,None,None,None],
]

for x in range(8):
  chessboard[1][x] = 'BPawn'
  chessboard[6][x] = 'WPawn'

# %%
chessboard
# Out:
# [[None, None, None, None, None, None, None, None],
#  ['BPawn', 'BPawn', 'BPawn', 'BPawn', 'BPawn', 'BPawn', 'BPawn', 'BPawn'],
#  [None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None],
#  ['WPawn', 'WPawn', 'WPawn', 'WPawn', 'WPawn', 'WPawn', 'WPawn', 'WPawn'],
#  [None, None, None, None, None, None, None, None]]

# %% [markdown]
# #Q3 Fill the other pieces for black ones as;
#
# * BRook
# * BNight
# * BBishop
# * BQueen
# * BKing
# * BBishop
# * BNight
# * BRook
#
#
# And for the white pieces;
# * WRook
# * WNight
# * WBishop
# * WQueen
# * WKing
# * WBishop
# * WNight
# * WRook

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
board = [
         ["BRook","BKnight","BBishop","BQueen","BKing","BBishop","BKnight","BRook"],
         ["BPawn","BPawn","BPawn","BPawn","BPawn","BPawn","BPawn","BPawn"],
         [None,None,None,None,None,None,None,None],
         [None,None,None,None,None,None,None,None],
         [None,None,None,None,None,None,None,None],
         [None,None,None,None,None,None,None,None],
         ["WPawn","WPawn","WPawn","WPawn","WPawn","WPawn","WPawn","WPawn"],
         ["WRook","WKnight","WBishop","WQueen","WKing","WBishop","WKnight","WRook"]
]

# %% [markdown]
# #Q4 Move the pieces
# Move one pieces from White  like Pawn moves forward **d4**, <br>
# and one pieces from Black side Pawn moves forward **d5**, <br>
# then turn to White and move **c4** which is the **Queen Gambit** variant one of the powerful openings in the chess game for white choice.
#
# To transform your list to represent the following diagram,
# you need to swap None items with the pieces from first location.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
board = [
         ["BRook","BKnight","BBishop","BQueen","BKing","BBishop","BKnight","BRook"],
         ["BPawn","BPawn","BPawn",None,"BPawn","BPawn","BPawn","BPawn"],
         [None,None,None,None,None,None,None,None],
         [None,None,None,"BPawn",None,None,None,None],
         [None,None,"WPawn","WPawn",None,None,None,None],
         [None,None,None,None,None,None,None,None],
         ["WPawn","WPawn",None,None,"WPawn","WPawn","WPawn","WPawn"],
         ["WRook","WKnight","WBishop","WQueen","WKing","WBishop","WKnight","WRook"]
]

# %% [markdown]
# #Q5 To program a better game, check to see if there is any other piece where the piece goes, if the player's own piece is not able to move, write it, if the opponent's piece is, delete that piece and place your piece there.
