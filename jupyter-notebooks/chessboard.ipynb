# %%
# !pip install chess
# Out:
# ERROR: Could not find a version that satisfies the requirement chess (from versions: none)
# ERROR: No matching distribution found for chess

# %%
import chess

#start a filled board
board = chess.Board()

# %%
#print the board
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1')

# %%
#define a movement from pawn e2 to e4
W1 = chess.Move.from_uci("e2e4")

#apply the movement on the game
board.push(W1)

# %%
#show board again and demonstrate the movement
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq - 0 1')

# %%
B1 = chess.Move.from_uci("e7e5")

#apply the movement on the game
board.push(B1)

# %%
board
# Out:
# Board('rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2')

# %%
W2 = chess.Move.from_uci("g1f3")

#apply the movement on the game
board.push(W2)

# %%
board
# Out:
# Board('rnbqkbnr/pppp1ppp/8/4p3/4P3/5N2/PPPP1PPP/RNBQKB1R b KQkq - 1 2')

# %%
B2 = chess.Move.from_uci("b8c6")

#apply the movement on the game
board.push(B2)

# %%
board
# Out:
# Board('r1bqkbnr/pppp1ppp/2n5/4p3/4P3/5N2/PPPP1PPP/RNBQKB1R w KQkq - 2 3')

# %%
W3 = chess.Move.from_uci("f1c4")

#apply the movement on the game
board.push(W3)

# %%
board
# Out:
# Board('r1bqkbnr/pppp1ppp/2n5/4p3/2B1P3/5N2/PPPP1PPP/RNBQK2R b KQkq - 3 3')

# %%
print(board)
# Out:
# r . b q k b n r
# p p p p . p p p
# . . n . . . . .
# . . . . p . . .
# . . B . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K . . R

# %%
board.is_game_over()
# Out:
# False

# %% [markdown]
# #Q1) Create the game diagram below. This opening is called Giuovo Piano.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Q2) Create the game diagram below. This opening is called Sicilian Defense Najdorf Variation

# %% [markdown]
# ![image.png](data:image/png;base64,...)
